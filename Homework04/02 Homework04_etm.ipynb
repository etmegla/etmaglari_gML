# %% [markdown]
# # SPATIAL INTELLIGENCE — PART 2
# ## Homework 04 — ETM

# %% [markdown]
# ## 1. Import the needed libraries

# %%
from topologicpy.Vertex import Vertex
from topologicpy.Edge import Edge
from topologicpy.Wire import Wire
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Dictionary import Dictionary
from topologicpy.Helper import Helper
from topologicpy.Grid import Grid
from topologicpy.Graph import Graph
from topologicpy.Color import Color

# %% [markdown]
# ## 2. Check the TopologicPy Version

# %%
print("This notebook requires topologicpy version 0.9.18 or newer.")
print(Helper.Version())

# %% [markdown]
# ## 3. Set your renderer
# * Visual Studio Code: `"vscode"`
# * Google Colab: `"colab"`
# * Browser: `"browser"`

# %%
renderer = "vscode"

# %% [markdown]
# ## 4. Utility functions

# %%
def reset_dictionaries(shell):
    faces = Topology.Faces(shell)
    for i, f in enumerate(faces):
        d = Topology.Dictionary(f)
        keys = Dictionary.Keys(d)
        for key in keys:
            if not key == 'face_id':
                d = Dictionary.RemoveKey(d, key)
        f = Topology.SetDictionary(f, d)

def transfer_dicts_by_key(topologies, selectors, key):
    dicts = {}
    for t in topologies:
        d = Topology.Dictionary(t)
        value = Dictionary.ValueAtKey(d, key, None)
        if value:
            dicts[str(value)] = t
    for s in selectors:
        d = Topology.Dictionary(s)
        value = Dictionary.ValueAtKey(d, key, None)
        if value:
            f = dicts.get(str(value), None)
            if f:
                f = Topology.SetDictionary(f, d)

# %% [markdown]
# ## 5. Load the floor plan outline (OBJ)

# %%
FLOOR_PLANS = r"C:\Users\etmaglari\IAAC\etmaglari_gML\Homework04\FloorPlans"
OBJ_PATH = FLOOR_PLANS + r"\GroungFloor.obj"

objects = Topology.ByOBJPath(OBJ_PATH)
if not isinstance(objects, list): objects = [objects]

# Ground floor OBJ contains a single large up-facing polygon — the building footprint
floor_outline = None
best_area = 0
for obj in objects:
    for f in (Topology.Faces(obj) or []):
        n = Face.Normal(f)
        if n[2] > 0.7:
            a = Face.Area(f)
            if a and a > best_area:
                best_area = a
                floor_outline = f

print("Floor outline loaded:", floor_outline is not None)

b_r = Wire.BoundingRectangle(floor_outline)
d_br = Topology.Dictionary(b_r)
xmin   = Dictionary.ValueAtKey(d_br, "xmin")
xmax   = Dictionary.ValueAtKey(d_br, "xmax")
ymin   = Dictionary.ValueAtKey(d_br, "ymin")
ymax   = Dictionary.ValueAtKey(d_br, "ymax")
width  = Dictionary.ValueAtKey(d_br, "width")
length = Dictionary.ValueAtKey(d_br, "length")

print(f"Bounds: x=[{xmin:.2f}, {xmax:.2f}]  y=[{ymin:.2f}, {ymax:.2f}]")
print(f"Size: {width:.2f} x {length:.2f} m")

# All four floors share the same footprint; translate to each floor elevation
FLOOR_LEVELS = [
    ("Ground Floor",  0.000),
    ("Level 1",       2.079),
    ("Level 2",       5.710),
    ("Level 3",       8.483),
]
floor_faces = []
for name, z in FLOOR_LEVELS:
    ff = Topology.Translate(floor_outline, 0, 0, z)
    floor_faces.append((name, z, ff))
    print(f"  {name}: z={z:.3f}")

# %% [markdown]
# ## 6. Show the floor plans

# %%
for name, z, ff in floor_faces:
    fc = Topology.Centroid(ff)
    cx, cy, cz = Vertex.X(fc), Vertex.Y(fc), Vertex.Z(fc)
    print(f"--- {name} ---")
    Topology.Show(ff,
                  camera=[0, 0, 6],
                  faceColor=[210, 210, 250], faceOpacity=1,
                  edgeColor="white", edgeWidth=3,
                  showVertices=False,
                  backgroundColor="black",
                  width=800, height=600, renderer=renderer)

# %% [markdown]
# ## 7. Build grid, shell, and analysis graph for each floor

# %%
GRID_STEP = 1
uRange = list(range(0, int(width)  + GRID_STEP, GRID_STEP))
vRange = list(range(0, int(length) + GRID_STEP, GRID_STEP))

shells, faces_list, g_verts_list = [], [], []
nav_graphs, ana_graphs = [], []

for name, z, ff in floor_faces:
    grid  = Grid.EdgesByDistances(ff, clip=True, uRange=uRange, vRange=vRange)
    shell = Topology.Slice(ff, grid)
    faces = Topology.Faces(shell)
    for i, f in enumerate(faces):
        Topology.SetDictionary(f, Dictionary.ByKeyValue("face_id", "face_" + str(i + 1)))
    nav_g = Graph.ByTopology(shell, direct=False, viaSharedTopologies=True)
    ana_g = Graph.ByTopology(shell)
    g_v   = Graph.Vertices(ana_g)
    shells.append(shell)
    faces_list.append(faces)
    g_verts_list.append(g_v)
    nav_graphs.append(nav_g)
    ana_graphs.append(ana_g)
    print(f"{name}: {len(faces)} cells, {len(g_v)} graph vertices")

# %% [markdown]
# ## 8. Spatial Intelligence through Graph Analysis
# ### a. Community Detection
# Community partitioning groups spatially connected grid cells into clusters. Each colour identifies one community.

# %%
for i, (name, z, ff) in enumerate(floor_faces):
    fc = Topology.Centroid(ff)
    cx, cy, cz = Vertex.X(fc), Vertex.Y(fc), Vertex.Z(fc)
    print(f"--- {name} — Community Detection ---")
    _ = Graph.CommunityPartition(ana_graphs[i], colorScale="thermal")
    reset_dictionaries(shells[i])
    faces_i = Topology.Faces(shells[i])
    transfer_dicts_by_key(faces_i, g_verts_list[i], "face_id")
    Topology.Show(faces_i,
                  faceColorKey="cp_color", faceOpacity=1,
                  showEdges=False, showVertices=False,
                  camera=[0, 0, 6],
                  backgroundColor="black",
                  width=800, height=600, renderer=renderer)

# %% [markdown]
# ### b. Degree Centrality
# Bin the grid faces by community, compute each community zone's outer boundary, build a coarser graph from those zones, compute degree centrality, then interpolate back onto the dense 1 m grid.

# %%
from topologicpy.Shell import Shell as ShellClass

for i, (name, z, ff) in enumerate(floor_faces):
    fc = Topology.Centroid(ff)
    cx, cy, cz = Vertex.X(fc), Vertex.Y(fc), Vertex.Z(fc)
    print(f"--- {name} — Degree Centrality ---")

    faces_i = Topology.Faces(shells[i])

    # Bin faces by community, derive outer boundary of each zone
    bins = Topology.BinByDictionaryKey(faces_i, key="community")
    bin_dict = bins[0]
    face_groups = []
    for key in list(bin_dict.keys()):
        temp_shell = ShellClass.ByFaces(bin_dict[key])
        if temp_shell is None:
            continue
        eb = ShellClass.ExternalBoundary(temp_shell)
        if eb is None:
            continue
        eb = Wire.RemoveCollinearEdges(eb)
        eb_face = Face.ByWire(eb)
        if eb_face:
            face_groups.append(eb_face)

    if not face_groups:
        print(f"  Skipping {name}: no valid community boundaries found")
        continue

    Topology.Show(face_groups,
                  faceOpacity=1, showEdges=True,
                  edgeWidth=8, edgeColor="grey",
                  camera=[0, 0, 6],
                  backgroundColor="black",
                  width=800, height=600, renderer=renderer)

    new_shell = ShellClass.ByFaces(face_groups)
    new_graph = Graph.ByTopology(new_shell)
    new_verts = Graph.Vertices(new_graph)
    for v in new_verts:
        Topology.SetDictionary(v, Dictionary.ByKeysValues(["color", "size"], ["red", 12]))

    dc_list = Graph.DegreeCentrality(new_graph, normalize=False)
    for v in g_verts_list[i]:
        Vertex.InterpolateValue(v, vertices=new_verts, n=3, key="degree_centrality")

    min_dc = min(dc_list)
    max_dc = max(dc_list)
    for v in g_verts_list[i]:
        d = Topology.Dictionary(v)
        dc = Dictionary.ValueAtKey(d, "degree_centrality")
        if dc is not None:
            color = Color.AnyToHex(Color.ByValueInRange(dc, minValue=min_dc, maxValue=max_dc, colorScale="thermal"))
            d = Dictionary.SetValueAtKey(d, "dc_color", color)
            Topology.SetDictionary(v, d)

    reset_dictionaries(shells[i])
    faces_upd = Topology.Faces(shells[i])
    transfer_dicts_by_key(faces_upd, g_verts_list[i], "face_id")
    Topology.Show(faces_upd,
                  faceColorKey="dc_color", faceOpacity=1,
                  showEdges=False, showVertices=False,
                  camera=[0, 0, 6],
                  backgroundColor="black",
                  width=800, height=600, renderer=renderer)
